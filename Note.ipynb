# %%
import pandas as pd

# Define the data for the algorithms and their requirements, including additional considerations
data = {
    "Algorithm": [
        "Exponential Smoothing with Trend and Seasonality",
        "Moving Average",
        "Least Squares Regression",
        "Weighted Moving Average",
        "Linear Smoothing (Simple Exponential Smoothing)",
        "Percent Over Last Year",
        "Calculated Percent Over Last Year",
        "Last Year to This Year",
        "Second Degree Approximation (Quadratic Model)",
        "Linear Regression",
        "Ridge Regression",
        "Lasso Regression",
        "Elastic Net",
        "Support Vector Regression (SVR)",
        "Decision Tree Regressor",
        "Random Forest Regressor",
        "Gradient Boosting Regressor",
        "XGBoost",
        "CatBoost",
        "Simple ARIMA (Non-seasonal)"
    ],
    "Minimum Data Points": [
        24, 20, 30, 20, 10, 12, 12, 12, 30, 10, 20, 20, 20, 30, 20, 30, 50, 50, 50, 20
    ],
    "Time Span Required": [
        "Minimum of 2 years",
        "Minimum of 1 year",
        "Minimum of 2 years",
        "Minimum of 1 year",
        "Minimum of 6 months",
        "Minimum of 2 years",
        "Minimum of 2 years",
        "Minimum of 2 years",
        "Minimum of 2 years",
        "Minimum of 3 months",
        "Minimum of 6 months",
        "Minimum of 6 months",
        "Minimum of 6 months",
        "Minimum of 6 months",
        "Minimum of 6 months",
        "Minimum of 6 months",
        "Minimum of 6 months",
        "Minimum of 6 months",
        "Minimum of 6 months",
        "Minimum of 6 months"
    ],
    "Suitable for Timeseries": [
        "Yes", "Limited", "Yes", "Limited", "Limited", "Limited", "Limited", "Limited", "Yes",
        "Yes", "Yes", "Yes", "Yes", "Yes", "Yes", "Yes", "Yes", "Yes", "Yes", "Yes"
    ],
    "Suitable for <6 Months Data": [
        "No", "No", "No", "No", "Yes", "No", "No", "No", "No", "Yes", "No", "No", "No", "No",
        "No", "No", "No", "No", "No", "Yes"
    ],
    "Other Considerations": [
        "Sensitive to trend and seasonal data",
        "Best for stable series without trends or seasonality",
        "Assumes linear relationship, sensitive to outliers",
        "Weights need to be defined, more weight to recent observations",
        "Does not consider trends or seasonality",
        "Compares same period across years",
        "May adjust comparison method",
        "Absolute difference between periods",
        "Captures curvature in data",
        "Simple linear relationship, sensitive to multicollinearity",
        "Includes penalty to reduce complexity",
        "Can set some coefficients to zero, variable selection",
        "Combines penalties of Ridge and Lasso",
        "Fit error within threshold, uses regularization",
        "Based on feature splits, can overfit",
        "Ensemble of trees, reduces overfitting",
        "Sequentially corrects previous errors, sensitive to outliers",
        "Efficient, scalable, sensitive to tuning parameters",
        "Handles categorical data efficiently",
        "Flexible model, requires stationary data"
    ]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#                                            Algorithm  Minimum Data Points  \
# 0   Exponential Smoothing with Trend and Seasonality                   24
# 1                                     Moving Average                   20
# 2                           Least Squares Regression                   30
# 3                            Weighted Moving Average                   20
# 4    Linear Smoothing (Simple Exponential Smoothing)                   10
# 5                             Percent Over Last Year                   12
# 6                  Calculated Percent Over Last Year                   12
# 7                             Last Year to This Year                   12
# 8      Second Degree Approximation (Quadratic Model)                   30
# 9                                  Linear Regression                   10
# 10                                  Ridge Regression                   20
# 11                                  Lasso Regression                   20
# 12                                       Elastic Net                   20
# 13                   Support Vector Regression (SVR)                   30
# 14                           Decision Tree Regressor                   20
# 15                           Random Forest Regressor                   30
# 16                       Gradient Boosting Regressor                   50
# 17                                           XGBoost                   50
# 18                                          CatBoost                   50
# 19                       Simple ARIMA (Non-seasonal)                   20
#
#      Time Span Required Suitable for Timeseries Suitable for <6 Months Data  \
# 0    Minimum of 2 years                     Yes                          No
# 1     Minimum of 1 year                 Limited                          No
# 2    Minimum of 2 years                     Yes                          No
# 3     Minimum of 1 year                 Limited                          No
# 4   Minimum of 6 months                 Limited                         Yes
# 5    Minimum of 2 years                 Limited                          No
# 6    Minimum of 2 years                 Limited                          No
# 7    Minimum of 2 years                 Limited                          No
# 8    Minimum of 2 years                     Yes                          No
# 9   Minimum of 3 months                     Yes                         Yes
# 10  Minimum of 6 months                     Yes                          No
# 11  Minimum of 6 months                     Yes                          No
# 12  Minimum of 6 months                     Yes                          No
# 13  Minimum of 6 months                     Yes                          No
# 14  Minimum of 6 months                     Yes                          No
# 15  Minimum of 6 months                     Yes                          No
# 16  Minimum of 6 months                     Yes                          No
# 17  Minimum of 6 months                     Yes                          No
# 18  Minimum of 6 months                     Yes                          No
# 19  Minimum of 6 months                     Yes                         Yes
#
#                                  Other Considerations
# 0                Sensitive to trend and seasonal data
# 1   Best for stable series without trends or seaso...
# 2   Assumes linear relationship, sensitive to outl...
# 3   Weights need to be defined, more weight to rec...
# 4             Does not consider trends or seasonality
# 5                   Compares same period across years
# 6                        May adjust comparison method
# 7                 Absolute difference between periods
# 8                          Captures curvature in data
# 9   Simple linear relationship, sensitive to multi...
# 10              Includes penalty to reduce complexity
# 11  Can set some coefficients to zero, variable se...
# 12              Combines penalties of Ridge and Lasso
# 13    Fit error within threshold, uses regularization
# 14               Based on feature splits, can overfit
# 15             Ensemble of trees, reduces overfitting
# 16  Sequentially corrects previous errors, sensiti...
# 17  Efficient, scalable, sensitive to tuning param...
# 18               Handles categorical data efficiently
# 19           Flexible model, requires stationary data

# %%
import pandas as pd

# Creating DataFrame with minimum data point requirements
data = {
    "Algorithm": [
        "Exponential Smoothing with Trend and Seasonality",
        "Moving Average",
        "Least Squares Regression",
        "Weighted Moving Average",
        "Linear Smoothing (Simple Exponential Smoothing)",
        "Percent Over Last Year",
        "Calculated Percent Over Last Year",
        "Last Year to This Year",
        "Second Degree Approximation (Quadratic Model)",
        "Linear Regression",
        "Ridge Regression",
        "Lasso Regression",
        "Elastic Net",
        "Support Vector Regression (SVR)",
        "Decision Tree Regressor",
        "Random Forest Regressor",
        "Gradient Boosting Regressor",
        "XGBoost",
        "CatBoost",
        "Simple ARIMA (Non-seasonal)",
        "Recurrent Neural Networks (RNN)",
        "Long Short-Term Memory (LSTM)",
        "Convolutional Neural Networks (CNN) for Time Series",
        "Transformer-based Forecasting Models"
    ],
    "Minimum Data Points": [
        "2-3 full seasonal cycles (24+ months)",
        "10-50 data points",
        "20+ data points",
        "10-50 data points",
        "20+ data points",
        "At least 12 months",
        "At least 24 months",
        "12+ months",
        "30+ data points",
        "30+ data points",
        "50-100+ data points",
        "50-100+ data points",
        "50-100+ data points",
        "100-500+ data points",
        "100-500+ data points",
        "500-1000+ data points",
        "500-1000+ data points",
        "500-1000+ data points",
        "500-1000+ data points",
        "50-100+ data points",
        "500-2000+ data points",
        "500-2000+ data points",
        "1000+ data points",
        "2000+ data points"
    ],
    "Reason": [
        "Needs enough historical data to capture trend and seasonality patterns.",
        "The window size determines the minimum requirement. A larger moving window needs more data.",
        "Can work with small samples but performs better with more historical trends.",
        "Requires enough past data points to weight and smooth fluctuations.",
        "Works well for short-term forecasts but needs some history to learn from trends.",
        "Requires year-over-year comparison.",
        "Needs two years of data to calculate percentage growth trends.",
        "Similar to percent over last year, needs one full year's data.",
        "Requires enough historical points to estimate a curve.",
        "Works better with larger datasets but can function with small sample sizes.",
        "Needs more data to avoid overfitting, especially with high-dimensional features.",
        "Requires a moderate dataset to properly shrink coefficients.",
        "Hybrid of Ridge & Lasso, needs similar dataset size.",
        "Requires more data to identify support vectors for complex relationships.",
        "More data helps avoid overfitting due to tree depth.",
        "Needs a large dataset to generate stable and diverse trees.",
        "More data improves boosting iterations' ability to refine predictions.",
        "Requires sufficient data to train multiple boosting rounds effectively.",
        "Handles categorical features well but needs high sample sizes.",
        "Requires enough observations to estimate autocorrelation and moving average components.",
        "Captures long-term dependencies in sequential data.",
        "Best for capturing both short-term fluctuations and long-term patterns.",
        "Extracts spatial and temporal dependencies in time-series data.",
        "Best for complex, high-dimensional time-series forecasting with long-term dependencies."
    ],
    "Category": [
        "Traditional Statistical",
        "Traditional Statistical",
        "Traditional Statistical",
        "Traditional Statistical",
        "Traditional Statistical",
        "Traditional Statistical",
        "Traditional Statistical",
        "Traditional Statistical",
        "Traditional Statistical",
        "Machine Learning",
        "Machine Learning",
        "Machine Learning",
        "Machine Learning",
        "Machine Learning",
        "Machine Learning",
        "Machine Learning",
        "Machine Learning",
        "Machine Learning",
        "Machine Learning",
        "Traditional Statistical",
        "Neural Networks",
        "Neural Networks",
        "Neural Networks",
        "Neural Networks"
    ]
}

# Creating DataFrame
df_min_data_points = pd.DataFrame(data)

# Display DataFrame
print(df_min_data_points)
# Out:
#                                             Algorithm  \
# 0    Exponential Smoothing with Trend and Seasonality
# 1                                      Moving Average
# 2                            Least Squares Regression
# 3                             Weighted Moving Average
# 4     Linear Smoothing (Simple Exponential Smoothing)
# 5                              Percent Over Last Year
# 6                   Calculated Percent Over Last Year
# 7                              Last Year to This Year
# 8       Second Degree Approximation (Quadratic Model)
# 9                                   Linear Regression
# 10                                   Ridge Regression
# 11                                   Lasso Regression
# 12                                        Elastic Net
# 13                    Support Vector Regression (SVR)
# 14                            Decision Tree Regressor
# 15                            Random Forest Regressor
# 16                        Gradient Boosting Regressor
# 17                                            XGBoost
# 18                                           CatBoost
# 19                        Simple ARIMA (Non-seasonal)
# 20                    Recurrent Neural Networks (RNN)
# 21                      Long Short-Term Memory (LSTM)
# 22  Convolutional Neural Networks (CNN) for Time S...
# 23               Transformer-based Forecasting Models
#
#                       Minimum Data Points  \
# 0   2-3 full seasonal cycles (24+ months)
# 1                       10-50 data points
# 2                         20+ data points
# 3                       10-50 data points
# 4                         20+ data points
# 5                      At least 12 months
# 6                      At least 24 months
# 7                              12+ months
# 8                         30+ data points
# 9                         30+ data points
# 10                    50-100+ data points
# 11                    50-100+ data points
# 12                    50-100+ data points
# 13                   100-500+ data points
# 14                   100-500+ data points
# 15                  500-1000+ data points
# 16                  500-1000+ data points
# 17                  500-1000+ data points
# 18                  500-1000+ data points
# 19                    50-100+ data points
# 20                  500-2000+ data points
# 21                  500-2000+ data points
# 22                      1000+ data points
# 23                      2000+ data points
#
#                                                Reason                 Category
# 0   Needs enough historical data to capture trend ...  Traditional Statistical
# 1   The window size determines the minimum require...  Traditional Statistical
# 2   Can work with small samples but performs bette...  Traditional Statistical
# 3   Requires enough past data points to weight and...  Traditional Statistical
# 4   Works well for short-term forecasts but needs ...  Traditional Statistical
# 5                 Requires year-over-year comparison.  Traditional Statistical
# 6   Needs two years of data to calculate percentag...  Traditional Statistical
# 7   Similar to percent over last year, needs one f...  Traditional Statistical
# 8   Requires enough historical points to estimate ...  Traditional Statistical
# 9   Works better with larger datasets but can func...         Machine Learning
# 10  Needs more data to avoid overfitting, especial...         Machine Learning
# 11  Requires a moderate dataset to properly shrink...         Machine Learning
# 12  Hybrid of Ridge & Lasso, needs similar dataset...         Machine Learning
# 13  Requires more data to identify support vectors...         Machine Learning
# 14  More data helps avoid overfitting due to tree ...         Machine Learning
# 15  Needs a large dataset to generate stable and d...         Machine Learning
# 16  More data improves boosting iterations' abilit...         Machine Learning
# 17  Requires sufficient data to train multiple boo...         Machine Learning
# 18  Handles categorical features well but needs hi...         Machine Learning
# 19  Requires enough observations to estimate autoc...  Traditional Statistical
# 20  Captures long-term dependencies in sequential ...          Neural Networks
# 21  Best for capturing both short-term fluctuation...          Neural Networks
# 22  Extracts spatial and temporal dependencies in ...          Neural Networks
# 23  Best for complex, high-dimensional time-series...          Neural Networks

# %%
# Debugging: Check the length of each list
for key, value in data.items():
    print(f"{key}: {len(value)}")
# Out:
# Algorithm: 24
# Minimum Data Points: 24
# Reason: 24
# Category: 24

# %%
df_min_data_points
# Out:
#                                             Algorithm  \
# 0    Exponential Smoothing with Trend and Seasonality
# 1                                      Moving Average
# 2                            Least Squares Regression
# 3                             Weighted Moving Average
# 4     Linear Smoothing (Simple Exponential Smoothing)
# 5                              Percent Over Last Year
# 6                   Calculated Percent Over Last Year
# 7                              Last Year to This Year
# 8       Second Degree Approximation (Quadratic Model)
# 9                                   Linear Regression
# 10                                   Ridge Regression
# 11                                   Lasso Regression
# 12                                        Elastic Net
# 13                    Support Vector Regression (SVR)
# 14                            Decision Tree Regressor
# 15                            Random Forest Regressor
# 16                        Gradient Boosting Regressor
# 17                                            XGBoost
# 18                                           CatBoost
# 19                        Simple ARIMA (Non-seasonal)
# 20                    Recurrent Neural Networks (RNN)
# 21                      Long Short-Term Memory (LSTM)
# 22  Convolutional Neural Networks (CNN) for Time S...
# 23               Transformer-based Forecasting Models
#
#                       Minimum Data Points  \
# 0   2-3 full seasonal cycles (24+ months)
# 1                       10-50 data points
# 2                         20+ data points
# 3                       10-50 data points
# 4                         20+ data points
# 5                      At least 12 months
# 6                      At least 24 months
# 7                              12+ months
# 8                         30+ data points
# 9                         30+ data points
# 10                    50-100+ data points
# 11                    50-100+ data points
# 12                    50-100+ data points
# 13                   100-500+ data points
# 14                   100-500+ data points
# 15                  500-1000+ data points
# 16                  500-1000+ data points
# 17                  500-1000+ data points
# 18                  500-1000+ data points
# 19                    50-100+ data points
# 20                  500-2000+ data points
# 21                  500-2000+ data points
# 22                      1000+ data points
# 23                      2000+ data points
#
#                                                Reason                 Category
# 0   Needs enough historical data to capture trend ...  Traditional Statistical
# 1   The window size determines the minimum require...  Traditional Statistical
# 2   Can work with small samples but performs bette...  Traditional Statistical
# 3   Requires enough past data points to weight and...  Traditional Statistical
# 4   Works well for short-term forecasts but needs ...  Traditional Statistical
# 5                 Requires year-over-year comparison.  Traditional Statistical
# 6   Needs two years of data to calculate percentag...  Traditional Statistical
# 7   Similar to percent over last year, needs one f...  Traditional Statistical
# 8   Requires enough historical points to estimate ...  Traditional Statistical
# 9   Works better with larger datasets but can func...         Machine Learning
# 10  Needs more data to avoid overfitting, especial...         Machine Learning
# 11  Requires a moderate dataset to properly shrink...         Machine Learning
# 12  Hybrid of Ridge & Lasso, needs similar dataset...         Machine Learning
# 13  Requires more data to identify support vectors...         Machine Learning
# 14  More data helps avoid overfitting due to tree ...         Machine Learning
# 15  Needs a large dataset to generate stable and d...         Machine Learning
# 16  More data improves boosting iterations' abilit...         Machine Learning
# 17  Requires sufficient data to train multiple boo...         Machine Learning
# 18  Handles categorical features well but needs hi...         Machine Learning
# 19  Requires enough observations to estimate autoc...  Traditional Statistical
# 20  Captures long-term dependencies in sequential ...          Neural Networks
# 21  Best for capturing both short-term fluctuation...          Neural Networks
# 22  Extracts spatial and temporal dependencies in ...          Neural Networks
# 23  Best for complex, high-dimensional time-series...          Neural Networks
