# %%
import pandas as pd


# Define the data with additional columns for daily, monthly, and yearly data points
data = {
    "Algorithm": [
        "Exponential Smoothing with Trend and Seasonality",
        "Moving Average",
        "Least Squares Regression",
        "Weighted Moving Average",
        "Linear Smoothing (Simple Exponential Smoothing)",
        "Percent Over Last Year",
        "Calculated Percent Over Last Year",
        "Last Year to This Year",
        "Second Degree Approximation (Quadratic Model)",
        "Linear Regression",
        "Ridge Regression",
        "Lasso Regression",
        "Elastic Net",
        "Support Vector Regression (SVR)",
        "Decision Tree Regressor",
        "Random Forest Regressor",
        "Gradient Boosting Regressor",
        "XGBoost",
        "CatBoost",
        "Simple ARIMA (Non-seasonal)",
        "Recurrent Neural Networks (RNN)",
        "Long Short-Term Memory (LSTM)",
        "Convolutional Neural Networks (CNN) for Time Series",
        "Transformer-based Forecasting Models"
    ],
    "Reason": [
        "Needs enough historical data to capture trend and seasonality patterns.",
        "The window size determines the minimum requirement.",
        "Can work with small samples but performs better with more historical trends.",
        "Requires enough past data points to weight and smooth fluctuations.",
        "Works well for short-term forecasts but needs some history to learn from trends.",
        "Requires year-over-year comparison.",
        "Needs two years of data to calculate percentage growth trends.",
        "Similar to percent over last year, needs one full year's data.",
        "Requires enough historical points to estimate a curve.",
        "Works better with larger datasets but can function with small sample sizes.",
        "Needs more data to avoid overfitting, especially with high-dimensional features.",
        "Requires a moderate dataset to properly shrink coefficients.",
        "Hybrid of Ridge & Lasso, needs similar dataset size.",
        "Requires more data to identify support vectors for complex relationships.",
        "More data helps avoid overfitting due to tree depth.",
        "Needs a large dataset to generate stable and diverse trees.",
        "More data improves boosting iterations' ability to refine predictions.",
        "Requires sufficient data to train multiple boosting rounds effectively.",
        "Handles categorical features well but needs high sample sizes.",
        "Requires enough observations to estimate autocorrelation and moving average components.",
        "Captures long-term dependencies in sequential data.",
        "Best for capturing both short-term fluctuations and long-term patterns.",
        "Extracts spatial and temporal dependencies in time-series data.",
        "Best for complex, high-dimensional time-series forecasting."
    ],
    "Category": [
        "Traditional Statistical", "Traditional Statistical", "Traditional Statistical", "Traditional Statistical", "Traditional Statistical",
        "Traditional Statistical", "Traditional Statistical", "Traditional Statistical", "Traditional Statistical", "Machine Learning",
        "Machine Learning", "Machine Learning", "Machine Learning", "Machine Learning", "Machine Learning", "Machine Learning", "Machine Learning", "Machine Learning",
        "Machine Learning", "Traditional Statistical", "Neural Networks", "Neural Networks", "Neural Networks", "Neural Networks"
    ],
    "Daily Data Points": [
        "2-3 full seasonal cycles (24+ months)", "10-50", "20+", "10-50", "20+", "At least 12 months", "At least 24 months", "12+ months", "30+", "30+",
        "50-100+", "50-100+", "50-100+", "100-500+", "100-500+", "500-1000+", "500-1000+", "500-1000+", "500-1000+", "50-100+", "500-2000+", "500-2000+", "1000+", "2000+"
    ],
    "Monthly Data Points": [
        "2-3 full seasonal cycles (24+ months)", "10-50", "20+", "10-50", "20+", "At least 12 months", "At least 24 months", "12+ months", "30+", "30+",
        "50-100+", "50-100+", "50-100+", "100-500+", "100-500+", "500-1000+", "500-1000+", "500-1000+", "500-1000+", "50-100+", "500-2000+", "500-2000+", "1000+", "2000+"
    ],
    "Yearly Data Points": [
        "2-3 full seasonal cycles (24+ months)", "10-50", "20+", "10-50", "20+", "At least 12 months", "At least 24 months", "12+ months", "30+", "30+",
        "50-100+", "50-100+", "50-100+", "100-500+", "100-500+", "500-1000+", "500-1000+", "500-1000+", "500-1000+", "50-100+", "500-2000+", "500-2000+", "1000+", "2000+"
    ]
}

# Create DataFrame
df_min_data_points = pd.DataFrame(data)

# Display DataFrame
df_min_data_points
# Out:
#                                             Algorithm  \
# 0    Exponential Smoothing with Trend and Seasonality
# 1                                      Moving Average
# 2                            Least Squares Regression
# 3                             Weighted Moving Average
# 4     Linear Smoothing (Simple Exponential Smoothing)
# 5                              Percent Over Last Year
# 6                   Calculated Percent Over Last Year
# 7                              Last Year to This Year
# 8       Second Degree Approximation (Quadratic Model)
# 9                                   Linear Regression
# 10                                   Ridge Regression
# 11                                   Lasso Regression
# 12                                        Elastic Net
# 13                    Support Vector Regression (SVR)
# 14                            Decision Tree Regressor
# 15                            Random Forest Regressor
# 16                        Gradient Boosting Regressor
# 17                                            XGBoost
# 18                                           CatBoost
# 19                        Simple ARIMA (Non-seasonal)
# 20                    Recurrent Neural Networks (RNN)
# 21                      Long Short-Term Memory (LSTM)
# 22  Convolutional Neural Networks (CNN) for Time S...
# 23               Transformer-based Forecasting Models
#
#                                                Reason  \
# 0   Needs enough historical data to capture trend ...
# 1   The window size determines the minimum require...
# 2   Can work with small samples but performs bette...
# 3   Requires enough past data points to weight and...
# 4   Works well for short-term forecasts but needs ...
# 5                 Requires year-over-year comparison.
# 6   Needs two years of data to calculate percentag...
# 7   Similar to percent over last year, needs one f...
# 8   Requires enough historical points to estimate ...
# 9   Works better with larger datasets but can func...
# 10  Needs more data to avoid overfitting, especial...
# 11  Requires a moderate dataset to properly shrink...
# 12  Hybrid of Ridge & Lasso, needs similar dataset...
# 13  Requires more data to identify support vectors...
# 14  More data helps avoid overfitting due to tree ...
# 15  Needs a large dataset to generate stable and d...
# 16  More data improves boosting iterations' abilit...
# 17  Requires sufficient data to train multiple boo...
# 18  Handles categorical features well but needs hi...
# 19  Requires enough observations to estimate autoc...
# 20  Captures long-term dependencies in sequential ...
# 21  Best for capturing both short-term fluctuation...
# 22  Extracts spatial and temporal dependencies in ...
# 23  Best for complex, high-dimensional time-series...
#
#                    Category                      Daily Data Points  \
# 0   Traditional Statistical  2-3 full seasonal cycles (24+ months)
# 1   Traditional Statistical                                  10-50
# 2   Traditional Statistical                                    20+
# 3   Traditional Statistical                                  10-50
# 4   Traditional Statistical                                    20+
# 5   Traditional Statistical                     At least 12 months
# 6   Traditional Statistical                     At least 24 months
# 7   Traditional Statistical                             12+ months
# 8   Traditional Statistical                                    30+
# 9          Machine Learning                                    30+
# 10         Machine Learning                                50-100+
# 11         Machine Learning                                50-100+
# 12         Machine Learning                                50-100+
# 13         Machine Learning                               100-500+
# 14         Machine Learning                               100-500+
# 15         Machine Learning                              500-1000+
# 16         Machine Learning                              500-1000+
# 17         Machine Learning                              500-1000+
# 18         Machine Learning                              500-1000+
# 19  Traditional Statistical                                50-100+
# 20          Neural Networks                              500-2000+
# 21          Neural Networks                              500-2000+
# 22          Neural Networks                                  1000+
# 23          Neural Networks                                  2000+
#
#                       Monthly Data Points  \
# 0   2-3 full seasonal cycles (24+ months)
# 1                                   10-50
# 2                                     20+
# 3                                   10-50
# 4                                     20+
# 5                      At least 12 months
# 6                      At least 24 months
# 7                              12+ months
# 8                                     30+
# 9                                     30+
# 10                                50-100+
# 11                                50-100+
# 12                                50-100+
# 13                               100-500+
# 14                               100-500+
# 15                              500-1000+
# 16                              500-1000+
# 17                              500-1000+
# 18                              500-1000+
# 19                                50-100+
# 20                              500-2000+
# 21                              500-2000+
# 22                                  1000+
# 23                                  2000+
#
#                        Yearly Data Points
# 0   2-3 full seasonal cycles (24+ months)
# 1                                   10-50
# 2                                     20+
# 3                                   10-50
# 4                                     20+
# 5                      At least 12 months
# 6                      At least 24 months
# 7                              12+ months
# 8                                     30+
# 9                                     30+
# 10                                50-100+
# 11                                50-100+
# 12                                50-100+
# 13                               100-500+
# 14                               100-500+
# 15                              500-1000+
# 16                              500-1000+
# 17                              500-1000+
# 18                              500-1000+
# 19                                50-100+
# 20                              500-2000+
# 21                              500-2000+
# 22                                  1000+
# 23                                  2000+

# %%
from prettytable import PrettyTable

# Initialize PrettyTable and add columns
table = PrettyTable(df_min_data_points.columns)

# Add rows from the DataFrame to PrettyTable
for row in df_min_data_points.values:
    table.add_row(row)

# Display the table
print(table)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 4
#       1 from prettytable import PrettyTable
#       3 # Initialize PrettyTable and add columns
# ----> 4 table = PrettyTable(df_min_data_points.columns)
#       6 # Add rows from the DataFrame to PrettyTable
#       7 for row in df_min_data_points.values:
#
# File /opt/anaconda3/lib/python3.11/site-packages/prettytable/prettytable.py:330, in PrettyTable.__init__(self, field_names, **kwargs)
#     328 self._none_format: dict[str, str | None] = {}
#     329 self._kwargs = {}
# --> 330 if field_names:
#     331     self.field_names = field_names
#     332 else:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3170, in Index.__nonzero__(self)
#    3168 @final
#    3169 def __nonzero__(self) -> NoReturn:
# -> 3170     raise ValueError(
#    3171         f"The truth value of a {type(self).__name__} is ambiguous. "
#    3172         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    3173     )
#
# ValueError: The truth value of a Index is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Out:
# Collecting prettytable
#   Downloading prettytable-3.14.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.11/site-packages (from prettytable) (0.2.5)
# Downloading prettytable-3.14.0-py3-none-any.whl (31 kB)
# Installing collected packages: prettytable
# Successfully installed prettytable-3.14.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 5
#       2 from prettytable import PrettyTable
#       4 # Initialize PrettyTable and add columns
# ----> 5 table = PrettyTable(df_min_data_points.columns)
#       6 for row in df_min_data_points.values:
#       7     table.add_row(row)
#
# File /opt/anaconda3/lib/python3.11/site-packages/prettytable/prettytable.py:330, in PrettyTable.__init__(self, field_names, **kwargs)
#     328 self._none_format: dict[str, str | None] = {}
#     329 self._kwargs = {}
# --> 330 if field_names:
#     331     self.field_names = field_names
#     332 else:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3170, in Index.__nonzero__(self)
#    3168 @final
#    3169 def __nonzero__(self) -> NoReturn:
# -> 3170     raise ValueError(
#    3171         f"The truth value of a {type(self).__name__} is ambiguous. "
#    3172         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    3173     )
#
# ValueError: The truth value of a Index is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Debugging: Check the length of each list
for key, value in data.items():
    print(f"{key}: {len(value)}")
# Out:
# Algorithm: 24
# Minimum Data Points: 24
# Reason: 24
# Category: 24

# %%
df_min_data_points
# Out:
#                                             Algorithm  \
# 0    Exponential Smoothing with Trend and Seasonality
# 1                                      Moving Average
# 2                            Least Squares Regression
# 3                             Weighted Moving Average
# 4     Linear Smoothing (Simple Exponential Smoothing)
# 5                              Percent Over Last Year
# 6                   Calculated Percent Over Last Year
# 7                              Last Year to This Year
# 8       Second Degree Approximation (Quadratic Model)
# 9                                   Linear Regression
# 10                                   Ridge Regression
# 11                                   Lasso Regression
# 12                                        Elastic Net
# 13                    Support Vector Regression (SVR)
# 14                            Decision Tree Regressor
# 15                            Random Forest Regressor
# 16                        Gradient Boosting Regressor
# 17                                            XGBoost
# 18                                           CatBoost
# 19                        Simple ARIMA (Non-seasonal)
# 20                    Recurrent Neural Networks (RNN)
# 21                      Long Short-Term Memory (LSTM)
# 22  Convolutional Neural Networks (CNN) for Time S...
# 23               Transformer-based Forecasting Models
#
#                       Minimum Data Points  \
# 0   2-3 full seasonal cycles (24+ months)
# 1                       10-50 data points
# 2                         20+ data points
# 3                       10-50 data points
# 4                         20+ data points
# 5                      At least 12 months
# 6                      At least 24 months
# 7                              12+ months
# 8                         30+ data points
# 9                         30+ data points
# 10                    50-100+ data points
# 11                    50-100+ data points
# 12                    50-100+ data points
# 13                   100-500+ data points
# 14                   100-500+ data points
# 15                  500-1000+ data points
# 16                  500-1000+ data points
# 17                  500-1000+ data points
# 18                  500-1000+ data points
# 19                    50-100+ data points
# 20                  500-2000+ data points
# 21                  500-2000+ data points
# 22                      1000+ data points
# 23                      2000+ data points
#
#                                                Reason                 Category
# 0   Needs enough historical data to capture trend ...  Traditional Statistical
# 1   The window size determines the minimum require...  Traditional Statistical
# 2   Can work with small samples but performs bette...  Traditional Statistical
# 3   Requires enough past data points to weight and...  Traditional Statistical
# 4   Works well for short-term forecasts but needs ...  Traditional Statistical
# 5                 Requires year-over-year comparison.  Traditional Statistical
# 6   Needs two years of data to calculate percentag...  Traditional Statistical
# 7   Similar to percent over last year, needs one f...  Traditional Statistical
# 8   Requires enough historical points to estimate ...  Traditional Statistical
# 9   Works better with larger datasets but can func...         Machine Learning
# 10  Needs more data to avoid overfitting, especial...         Machine Learning
# 11  Requires a moderate dataset to properly shrink...         Machine Learning
# 12  Hybrid of Ridge & Lasso, needs similar dataset...         Machine Learning
# 13  Requires more data to identify support vectors...         Machine Learning
# 14  More data helps avoid overfitting due to tree ...         Machine Learning
# 15  Needs a large dataset to generate stable and d...         Machine Learning
# 16  More data improves boosting iterations' abilit...         Machine Learning
# 17  Requires sufficient data to train multiple boo...         Machine Learning
# 18  Handles categorical features well but needs hi...         Machine Learning
# 19  Requires enough observations to estimate autoc...  Traditional Statistical
# 20  Captures long-term dependencies in sequential ...          Neural Networks
# 21  Best for capturing both short-term fluctuation...          Neural Networks
# 22  Extracts spatial and temporal dependencies in ...          Neural Networks
# 23  Best for complex, high-dimensional time-series...          Neural Networks
